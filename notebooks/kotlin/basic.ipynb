// %% [markdown]
// # Kotlin 基础
//
// ## 变量定义
//
// - `val` 关键字定义只读变量
// - `var` 关键字定义可变变量

// %%
val name = "Genesis";
var version = "0.0.1";

println("项目名：${name}，版本号：${version}");

version = "0.0.2";

println("项目名：${name}，版本号：${version}");
